# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
# Set up figure size and DPI for screen demo
plt.rcParams['figure.figsize'] = (4,3)
plt.rcParams['figure.dpi'] = 150

# %%
from scipy.ndimage.filters import gaussian_filter
rands2d = gaussian_filter(np.random.normal(size=(512,512)), sigma=10)

# %%
plt.imshow(rands2d)
plt.colorbar()

# %%
plt.imshow(rands2d, extent=[0,100,-100, 0])

# %%
plt.imshow(rands2d, vmax=0.3, vmin= 0) 
plt.colorbar()

# %%
plt.imshow(rands2d, extent=[0,100,-100, 0], vmax=0.1, vmin= -0.05) 
plt.colorbar()

# %%
plt.imshow(rands2d, aspect=2) # 0.... 1 horizontal, vertical

# %%
small = np.arange(0,4,1).reshape(2,2)

print(small)

plt.imshow(small, interpolation='lanczos')

plt.matshow(small)  # helper function, deshabilita la interpolacion y usa los valores en el centro

"""
[None, 'none', 'nearest', 'bilinear', 'bicubic', 'spline16',
           'spline36', 'hanning', 'hamming', 'hermite', 'kaiser', 'quadric',
           'catrom', 'gaussian', 'bessel', 'mitchell', 'sinc', 'lanczos']
"""
# Out:
# [[0 1]
#  [2 3]]
# "\n[None, 'none', 'nearest', 'bilinear', 'bicubic', 'spline16',\n           'spline36', 'hanning', 'hamming', 'hermite', 'kaiser', 'quadric',\n           'catrom', 'gaussian', 'bessel', 'mitchell', 'sinc', 'lanczos']\n"
